# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_grad = pd.read_csv('/Users/ram/Desktop/K2DataScience/recent-grads.csv', low_memory = False)
data_grad.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2405                       CHEMICAL ENGINEERING    Engineering
#
#    Total  Sample_size    Men  Women  ShareWomen  Employed      ...        \
# 0   2339           36   2057    282    0.120564      1976      ...
# 1    756            7    679     77    0.101852       640      ...
# 2    856            3    725    131    0.153037       648      ...
# 3   1258           16   1123    135    0.107313       758      ...
# 4  32260          289  21239  11021    0.341631     25694      ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
data_grad.tail()
# Out:
#      Rank  Major_code                   Major            Major_category  \
# 168   169        3609                 ZOOLOGY    Biology & Life Science
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  Psychology & Social Work
# 170   171        5202     CLINICAL PSYCHOLOGY  Psychology & Social Work
# 171   172        5203   COUNSELING PSYCHOLOGY  Psychology & Social Work
# 172   173        3501         LIBRARY SCIENCE                 Education
#
#      Total  Sample_size   Men  Women  ShareWomen  Employed      ...        \
# 168   8409           47  3050   5359    0.637293      6259      ...
# 169   2854            7   522   2332    0.817099      2125      ...
# 170   2838           13   568   2270    0.799859      2101      ...
# 171   4626           21   931   3695    0.798746      3777      ...
# 172   1098            2   134    964    0.877960       742      ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
data_grad.dtypes
# Out:
# Rank                      int64
# Major_code                int64
# Major                    object
# Major_category           object
# Total                     int64
# Sample_size               int64
# Men                       int64
# Women                     int64
# ShareWomen              float64
# Employed                  int64
# Full_time                 int64
# Part_time                 int64
# Full_time_year_round      int64
# Unemployed                int64
# Unemployment_rate       float64
# Median                    int64
# P25th                     int64
# P75th                     int64
# College_jobs              int64
# Non_college_jobs          int64
# Low_wage_jobs             int64
# dtype: object

# %%
data_grad = data_grad.dropna()

# %%
data_grad.plot.scatter('Sample_size', 'Median')

# %%
data_grad.plot.scatter('Sample_size', 'Unemployment_rate')

# %%
data_grad.plot.scatter('Full_time', 'Median')

# %%
data_grad.plot.scatter('Men', 'Median')

# %%
data_grad.plot.scatter('Women', 'Median')

# %%
data_grad.plot.hist(y='Sample_size')

# %%
names_col = ['Sample_size', 'Median', 'Employed', 'Full_time', 'Unemployment_rate', 'Men', 'Women' ]

for i in names_col:
    data_grad.plot.hist(y=i)

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(data_grad[['Sample_size', 'Median']],figsize = (7,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x117e64128>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117f27898>]], dtype=object)

# %%
scatter_matrix(data_grad[['Sample_size', 'Median','Unemployment_rate']],figsize = (7,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x117fcaba8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11704b0b8>]], dtype=object)

# %%
data_grad[0:20].plot.bar('Major','ShareWomen')

# %%
data_grad[21:35].plot.bar('Major','ShareWomen')

# %%
data_grad[67:80].plot.bar('Major','ShareWomen')

# %%
data_grad[100:120].plot.bar('Major','ShareWomen')

# %%
data_grad[140:155].plot.bar('Major','ShareWomen')

# %%
data_grad[156:].plot.bar('Major','ShareWomen')
